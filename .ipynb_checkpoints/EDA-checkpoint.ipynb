# %% [markdown]
# # Time series exploration

# %%
#imports
import json
import math
# import LatLon
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

# %%
with open("./data/carpark_data.json", "r") as f:
    dataset = json.load(f)

# %%
carpark_list = []
for carpark in dataset:
    carpark_list.append(carpark)

# %%
#number of carparks
print(len(carpark_list))
# Out:
# 1936

# %% [markdown]
# ### Time series for a carpark

# %%
carpark_list[0]
# Out:
# 'HE12'

# %%
#collect data
utilisation = dataset[carpark_list[0]]['util_pct']
time = dataset[carpark_list[0]]['timestamp']

# %%
#parse datestring
timestamp = [datetime.strptime(x[:-6], '%Y-%m-%dT%H') for x in time]

# %%
df = pd.DataFrame({'utilisation':utilisation})
df.index = timestamp

# %%
plt.figure(figsize=(100, 5))
plt.plot(df)
plt.savefig("EDA/example-timeseries.jpg")

# %% [markdown]
# #### Exploring changes with variables

# %%
#exploring daily average
day_of_week = [x.weekday() for x in timestamp]

# %%
df["day_of_week"] = day_of_week

# %%
daily_util = df.groupby("day_of_week").mean()
daily_util
# Out:
#              utilisation
# day_of_week
# 0               0.788198
# 1               0.873339
# 2               0.855142
# 3               0.854284
# 4               0.885146
# 5               0.888505
# 6               0.844135

# %%
sns.barplot(x=daily_util.index, y=daily_util['utilisation'])
plt.title("Daily mean utilisation percentage (%)")
plt.savefig("EDA/daily-mean-util-pct.jpg")
plt.show()

# %% [markdown]
# There seems to be no difference in the utilisation percentages between days other than the noticeable decline in utilisation on monday (0)

# %%
#exploring hour of day
hour_of_day = [x.hour for x in timestamp]

# %%
df["hour"] = hour_of_day

# %%
hourly_util = df.groupby("hour").mean()
hourly_util
# Out:
#       utilisation  day_of_week
# hour
# 0        0.516793     2.896552
# 1        0.501310     2.896552
# 2        0.531966     2.896552
# 3        0.637467     2.966667
# 4        0.756600     2.966667
# 5        0.816367     2.966667
# 6        0.937333     2.966667
# 7        0.953067     2.966667
# 8        0.976581     2.903226
# 9        1.000000     2.903226
# 10       1.000000     2.903226
# 11       1.000000     2.903226
# 12       0.993613     2.903226
# 13       0.994500     2.900000
# 14       0.980200     2.900000
# 15       0.984233     2.900000
# 16       0.973233     2.900000
# 17       0.977267     2.900000
# 18       0.988633     2.900000
# 19       0.985333     2.900000
# 20       0.929233     2.900000
# 21       0.819600     2.900000
# 22       0.666833     2.900000
# 23       0.561067     2.900000

# %%
sns.barplot(x=hourly_util.index, y=hourly_util['utilisation'])
plt.title("Hourly mean utilisation percentage (%)")
plt.savefig("EDA/hourly-mean-util-pct.jpg")
plt.show()

# %% [markdown]
# There is low utilisation in the early hours and maximum utilisation between the hours of 9 and 6 (working hours)

# %% [markdown]
# ## Dealing with missing value

# %% [markdown]
# Our data is missing 1 date in the 30 days we have recorded.

# %%
#for each timestamp after the first, check if timestamp is 1 hour ahead of the previous timestamp
for timestamp in range(1, len(df.index)):
    if df.index[timestamp] - pd.DateOffset(hours=1) != df.index[timestamp - 1]:
        print(df.index[timestamp])
        print(timestamp)
# Out:
# 2021-05-08 03:00:00
# 592

# %%
df.index[[591,592]]
# Out:
# DatetimeIndex(['2021-05-07 23:00:00', '2021-05-08 03:00:00'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# There is a gap of 3 hours of data missing from all carpark data. Impute

# %%
#imputation via interpolation
# for dex in range(len(df.index)-1):
#     if df.index[dex] + pd.DateOffset(hours=1) != df.index[dex - 1]:
#         temp = list(df.index).insert(dex+1, (df.index[dex] + pd.DateOffset(hours=1)))
#         df.index = temp
#         df['utilisation'].insert(dex+1, np.nan)
#imputation via interpolation
for dex in range(len(dataset["HE12"]["timestamp"])-1):
    #parse string to date
    required_stamp = datetime.strptime(dataset["HE12"]["timestamp"][dex], '%Y-%m-%dT%H:%M:%S') + timedelta(hours=1)
    actual_stamp = datetime.strptime(dataset["HE12"]["timestamp"][dex+1], '%Y-%m-%dT%H:%M:%S')
    if required_stamp !=  actual_stamp:
        dataset["HE12"]["timestamp"].insert(dex+1, required_stamp.strftime('%Y-%m-%dT%H:%M:%S'))
        dataset["HE12"]["util_pct"].insert(dex+1, np.nan)

# %%
df.interpolate()
# Out:
#                      utilisation  day_of_week  hour
# 2021-04-13 08:00:00          1.0            1     8
# 2021-04-13 09:00:00          1.0            1     9
# 2021-04-13 10:00:00          1.0            1    10
# 2021-04-13 11:00:00          1.0            1    11
# 2021-04-13 12:00:00          1.0            1    12
# ...                          ...          ...   ...
# 2021-05-13 08:00:00          1.0            3     8
# 2021-05-13 09:00:00          1.0            3     9
# 2021-05-13 10:00:00          1.0            3    10
# 2021-05-13 11:00:00          1.0            3    11
# 2021-05-13 12:00:00          1.0            3    12
#
# [722 rows x 3 columns]

# %% [markdown]
# ## Converting SVY21 coordinate system to LatLon

# %%
from src.SVY21 import SVY21

# %%
cv = SVY21()

# %%
#cv.computeLatLon(y-coord/x-coord)
cv.computeLatLon(30069.2434, 26367.5806)
# Out:
# (1.2882093564649053, 103.81865029073313)
